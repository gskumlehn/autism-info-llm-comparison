# %% [markdown]
# <a href="https://colab.research.google.com/github/gskumlehn/autism-info-llm-comparison/blob/main/flesch_kincaid_grade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gskumlehn/autism-info-llm-comparison.git
# !pip install textstat
# Out:
# fatal: destination path 'autism-info-llm-comparison' already exists and is not an empty directory.
# ...

# %%
import pandas as pd

df = pd.read_csv("autism-info-llm-comparison/data.csv")
df.head()
# Out:
#                                            Questions  \
# 0                 What is autism spectrum disorders?
# 1  Which are the abilities and need of individual...
# 2  Which are the co-occurring conditions of autis...
# 3  What is the epidemiology of autism spectrum di...
# 4  What are the causes of autism spectrum disorders?
#
#                                                  WHO  \
# 0  Autism spectrum disorders (ASD) are a diverse ...
# 1  The abilities and needs of autistic people var...
# 2  People with autism often have co-occurring con...
# 3  It is estimated that worldwide about 1 in 100 ...
# 4  Available scientific evidence suggests that th...
#
#                                          ChatGPT 4.0  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Individuals with autism spectrum disorders (AS...
# 2  Common co-occurring conditions in individuals ...
# 3  The epidemiology of autism spectrum disorders ...
# ...

# %%
answers = df.iloc[:, 1:]
answers.head()
# Out:
#                                                  WHO  \
# 0  Autism spectrum disorders (ASD) are a diverse ...
# 1  The abilities and needs of autistic people var...
# 2  People with autism often have co-occurring con...
# 3  It is estimated that worldwide about 1 in 100 ...
# 4  Available scientific evidence suggests that th...
#
#                                          ChatGPT 4.0  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Individuals with autism spectrum disorders (AS...
# 2  Common co-occurring conditions in individuals ...
# 3  The epidemiology of autism spectrum disorders ...
# 4  The causes of autism spectrum disorders (ASD) ...
#
#                                       ChatGPT Vision  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Abilities:\n\nStrong attention to detail and p...
# 2  Common co-occurring conditions with Autism Spe...
# 3  The epidemiology of Autism Spectrum Disorders ...
# ...

# %%
import textstat
kincaid_grade_df = answers.map(textstat.flesch_kincaid_grade)

kincaid_grade_question_means = kincaid_grade_df.mean(axis=1)

kincaid_grade_df["Média"] = kincaid_grade_question_means

print(kincaid_grade_df)
# Out:
#     WHO  ChatGPT 4.0  ChatGPT Vision  ScholarGPT  Gemini  Llama3  \
# 0  14.6         18.4            15.2        15.8    15.2    17.8
# 1  12.0         14.2            11.8        14.6    15.2    27.2
# 2  19.0         17.4            16.2        16.0    15.0    19.8
# 3   9.3         13.5             9.0        13.9    12.5    22.0
# 4  14.1         11.9            11.6        14.2    11.9    20.7
# 5  15.6         15.9            13.6        15.5    16.1    16.7
# 6  14.5         13.6            14.8        15.0     9.9    32.6
# 7  17.4         14.2            12.6        14.4    16.8    32.6
#
#    Bing AI (Copilot)  Google Palm  Claude  ReKa Core  Solar Mini      Média
# 0               15.8         14.7    19.6       12.7        16.2  16.000000
# 1               13.6         30.6    56.8       14.6        13.2  20.345455
# 2               15.1         23.6    56.5       16.5        34.2  22.663636
# 3                9.7         12.1    66.9       12.2        12.7  17.618182
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.set_palette("crest")
sns.lineplot(data=kincaid_grade_df, linewidth=2)

plt.title("Kincaid Grade by Answer for Each Question", fontsize=16)
plt.xlabel("Question Number", fontsize=12)
plt.ylabel("Kincaid Grade", fontsize=12)
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)])

plt.show()

# %%
kincaid_grade_means = kincaid_grade_df.mean()
print(kincaid_grade_means)
# Out:
# WHO                  14.562500
# ChatGPT 4.0          14.887500
# ChatGPT Vision       13.100000
# ScholarGPT           14.925000
# Gemini               14.075000
# Llama3               23.675000
# Bing AI (Copilot)    13.725000
# Google Palm          17.175000
# Claude               55.000000
# ReKa Core            15.125000
# Solar Mini           18.125000
# Média                19.488636
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
kincaid_grade_means.plot(kind='bar', color='skyblue')
plt.title('Kincaid grade average for each source')
plt.xlabel('Source')
plt.ylabel('Kincaid grade mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
kincaid_grade_question_means.plot(kind='bar', color='skyblue')
plt.title('Kincaid grade average for each question')
plt.xlabel('Questions')
plt.ylabel('Kincaid grade mean')
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)], rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.set_palette("crest")
sns.lineplot(data=kincaid_grade_df, linewidth=2)

plt.title("Graduação Flesch-Kincaid por pergunta", fontsize=16)
plt.xlabel("Pergunta", fontsize=12)
plt.ylabel("Graduação Flesch-Kincaid", fontsize=12)
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)])

plt.show()

# %%
plt.figure(figsize=(10, 6))
kincaid_grade_means.plot(kind='bar', color='skyblue')
plt.title('Graduação Flesch-Kincaid média para cada fonte')
plt.xlabel('Fonte')
plt.ylabel('Graduação Flesch-Kincaid média')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
kincaid_grade_question_means.plot(kind='bar', color='skyblue')
plt.title('Graduação Flesch-Kincaid média para cada pergunta')
plt.xlabel('Pergunta')
plt.ylabel('Graduação Flesch-Kincaid média')
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)], rotation=0)
plt.tight_layout()
plt.show()

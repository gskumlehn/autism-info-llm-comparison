# %% [markdown]
# <a href="https://colab.research.google.com/github/gskumlehn/autism-info-llm-comparison/blob/main/flesch_reading_ease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gskumlehn/autism-info-llm-comparison.git
# Out:
# fatal: destination path 'autism-info-llm-comparison' already exists and is not an empty directory.

# %%
# !git clone https://github.com/gskumlehn/autism-info-llm-comparison.git
# !pip install textstat
# Out:
# fatal: destination path 'autism-info-llm-comparison' already exists and is not an empty directory.
# ...

# %%
import pandas as pd

df = pd.read_csv("autism-info-llm-comparison/data.csv")
df.head()
# Out:
#                                            Questions  \
# 0                 What is autism spectrum disorders?
# 1  Which are the abilities and need of individual...
# 2  Which are the co-occurring conditions of autis...
# 3  What is the epidemiology of autism spectrum di...
# 4  What are the causes of autism spectrum disorders?
#
#                                                  WHO  \
# 0  Autism spectrum disorders (ASD) are a diverse ...
# 1  The abilities and needs of autistic people var...
# 2  People with autism often have co-occurring con...
# 3  It is estimated that worldwide about 1 in 100 ...
# 4  Available scientific evidence suggests that th...
#
#                                          ChatGPT 4.0  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Individuals with autism spectrum disorders (AS...
# 2  Common co-occurring conditions in individuals ...
# 3  The epidemiology of autism spectrum disorders ...
# ...

# %%
answers = df.iloc[:, 1:]
answers.head()
# Out:
#                                                  WHO  \
# 0  Autism spectrum disorders (ASD) are a diverse ...
# 1  The abilities and needs of autistic people var...
# 2  People with autism often have co-occurring con...
# 3  It is estimated that worldwide about 1 in 100 ...
# 4  Available scientific evidence suggests that th...
#
#                                          ChatGPT 4.0  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Individuals with autism spectrum disorders (AS...
# 2  Common co-occurring conditions in individuals ...
# 3  The epidemiology of autism spectrum disorders ...
# 4  The causes of autism spectrum disorders (ASD) ...
#
#                                       ChatGPT Vision  \
# 0  Autism Spectrum Disorders (ASD) are a group of...
# 1  Abilities:\n\nStrong attention to detail and p...
# 2  Common co-occurring conditions with Autism Spe...
# 3  The epidemiology of Autism Spectrum Disorders ...
# ...

# %%
import textstat

reading_ease_df = answers.map(textstat.flesch_reading_ease)

reading_ease_question_means = reading_ease_df.mean(axis=1)

reading_ease_df["Média"] = reading_ease_question_means

print(reading_ease_df)
# Out:
#      WHO  ChatGPT 4.0  ChatGPT Vision  ScholarGPT  Gemini  Llama3  \
# 0  20.38        -5.52           13.65       17.34   18.86    1.43
# 1  38.11        16.18           22.37       15.17   18.86  -33.77
# 2  -1.63       -13.71          -10.66        0.58   24.78  -25.31
# 3  50.53        28.74           51.24       27.72   36.79   17.34
# 4  37.84        27.38           33.61       21.60   43.73   -0.78
# 5  23.26         0.99           12.19        2.00    5.69   -6.47
# 6  26.20        17.60           25.29       24.78   54.22  -20.90
# 7  18.69        21.50           31.07       20.99   20.21  -26.32
#
#    Bing AI (Copilot)  Google Palm  Claude  ReKa Core  Solar Mini      Média
# 0              17.34        25.49    2.07      30.77       27.15  15.360000
# 1              23.12       -26.66 -105.49      20.38       29.45   1.610909
# 2              13.75        -8.39 -136.97      -0.75      -41.21 -18.138182
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.set_palette("crest")
sns.lineplot(data=reading_ease_df, linewidth=2)

plt.title("Reading ease by Answer for Each Question", fontsize=16)
plt.xlabel("Question Number", fontsize=12)
plt.ylabel("Reading ease", fontsize=12)
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)])

plt.show()

# %%
reading_ease_means = reading_ease_df.mean()
print(reading_ease_means)
# Out:
# WHO                   26.672500
# ChatGPT 4.0           11.645000
# ChatGPT Vision        22.345000
# ScholarGPT            16.272500
# Gemini                27.892500
# Llama3               -11.847500
# Bing AI (Copilot)     26.763750
# Google Palm           17.765000
# Claude              -104.883750
# ReKa Core             19.060000
# Solar Mini            14.692500
# Média                  6.034318
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
reading_ease_means.plot(kind='bar', color='skyblue')
plt.title('Reading ease average for each source')
plt.xlabel('Source')
plt.ylabel('Reading ease mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
reading_ease_question_means.plot(kind='bar', color='skyblue')
plt.title('Reading ease average for each question')
plt.xlabel('Questions')
plt.ylabel('Reading ease mean')
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)], rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.set_palette("crest")
sns.lineplot(data=reading_ease_df, linewidth=2)

plt.title("Índice de leitura de Flesch por pergunta", fontsize=16)
plt.xlabel("Pergunta", fontsize=12)
plt.ylabel("Índice de leitura de Flesch", fontsize=12)
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)])

plt.show()

# %%
plt.figure(figsize=(10, 6))
reading_ease_means.plot(kind='bar', color='skyblue')
plt.title('Índice de leitura de Flesch média para cada fonte')
plt.xlabel('Fonte')
plt.ylabel('Índice de leitura de Flesch média')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
reading_ease_question_means.plot(kind='bar', color='skyblue')
plt.title('Índice de leitura de Flesch média para cada pergunta')
plt.xlabel('Pergunta')
plt.ylabel('Índice de leitura de Flesch média')
plt.xticks(ticks=range(8), labels=[str(i+1) for i in range(8)], rotation=0)
plt.tight_layout()
plt.show()
